# %%
import pandas as pd

# %%
df = pd.read_csv('WVS_Cross-National_Wave_7_csv_v1_6_2.csv', low_memory=False)

# %%
df.head()
# Out:
#               version                       doi  A_WAVE  A_STUDY  B_COUNTRY  \
# 0  1-6-2 (2021-04-25)  doi.org/10.14281/18241.1       7        2         20
# 1  1-6-2 (2021-04-25)  doi.org/10.14281/18241.1       7        2         20
# 2  1-6-2 (2021-04-25)  doi.org/10.14281/18241.1       7        2         20
# 3  1-6-2 (2021-04-25)  doi.org/10.14281/18241.1       7        2         20
# 4  1-6-2 (2021-04-25)  doi.org/10.14281/18241.1       7        2         20
#
#   B_COUNTRY_ALPHA  C_COW_NUM C_COW_ALPHA  A_YEAR  D_INTERVIEW  ...  \
# 0             AND        232         AND    2018     20070001  ...
# 1             AND        232         AND    2018     20070002  ...
# 2             AND        232         AND    2018     20070003  ...
# 3             AND        232         AND    2018     20070004  ...
# 4             AND        232         AND    2018     20070005  ...
#
#    WVS_Polmistrust_PartyVoter  WVS_LR_MedianVoter  WVS_LibCon_MedianVoter  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70867 entries, 0 to 70866
# Columns: 548 entries, version to v2xps_party
# dtypes: float64(523), int64(16), object(9)
# memory usage: 296.3+ MB

# %%
n =df.loc[:,"Q18":"Q26"]

nachbarn= (n['Q18']+n['Q19']+n['Q20']+n['Q21']+n['Q22']+n['Q23']+n['Q24']+n['Q26']+n['Q25'])/9
nachbarn = pd.DataFrame(nachbarn, columns=['nachbarn'])
t =df.loc[:,"Q58":"Q63"]

trust= (t['Q58']+t['Q59']+t['Q60']+t['Q61']+t['Q62']+t['Q63'])/6
trust = pd.DataFrame(trust, columns=['trust'])

a = df.loc[:,"Q94":"Q105"]
active= (a['Q94']+a['Q95']+a['Q96']+a['Q97']+a['Q98']+a['Q99']+a['Q100']+a['Q101']+a['Q102']+a['Q104']+a['Q105'])/len(a.columns)
active = pd.DataFrame(active, columns=['active'])

main_goal = pd.DataFrame(df['Q27'].rename('main_goal'))
financial = pd.DataFrame(df['Q50'].rename('financial'))
court = pd.DataFrame(df['Q70'].rename('court'))
comparing_parents = pd.DataFrame(df['Q56'].rename('comparing_parents'))
family = pd.DataFrame(df['Q1'].rename('family'))
work = pd.DataFrame(df['Q5'].rename('work'))

df_m = pd.concat([nachbarn,trust,active, financial, main_goal, court, comparing_parents, family, work],1)

# %%
economic_values = pd.DataFrame(df['Q106'].rename('economic_values'))

corruption_preceptions = pd.DataFrame(df['Q112'].rename('corruption_preceptions'))

corruption_of_institutions = (df['Q113']+df['Q114']+df['Q115']+df['Q116']+df['Q117'])/5
corruption_of_institutions = pd.DataFrame(corruption_of_institutions, columns=['corruption_of_institutions'])

effect_of_immigration = (df['Q122']+df['Q123']+df['Q124']+df['Q125']+df['Q126']+df['Q127']+df['Q128']+df['Q129'])/8
effect_of_immigration = pd.DataFrame(effect_of_immigration, columns=['effect_of_immigration'])

secure_in_neighborhood = (df['Q132']+df['Q133']+df['Q134']+df['Q135']+df['Q136']+df['Q137']+df['Q138'])/7
secure_in_neighborhood = pd.DataFrame(secure_in_neighborhood, columns=['secure_in_neighborhood'])

worried_about_risks_and_war = (df['Q142']+df['Q143']+df['Q146']+df['Q147']+df['Q148'])/5
worried_about_risks_and_war = pd.DataFrame(worried_about_risks_and_war, columns=['worried_about_risks_and_war'])


science_and_technologie = (df['Q158']+df['Q159']+df['Q160']+df['Q161']+df['Q162']+df['Q163']) / 6
science_and_technologie = pd.DataFrame(science_and_technologie, columns=['science_and_technologie'])

importance_of_god = pd.DataFrame(df['Q164'].rename('importance_of_god'))

religion_and_science = (df['Q169']+df['Q170'])/2
religion_and_science = pd.DataFrame(religion_and_science, columns=['religion_and_science'])

moral_rules = pd.DataFrame(df['Q176'].rename('moral_rules'))

Ethical_justification = (df['Q179']+df['Q180']+df['Q181']+df['Q182']+df['Q183']+df['Q184']+df['Q185']+df['Q186']+df['Q187']+df['Q188']+df['Q189']+df['Q190']+df['Q191']+df['Q192']+df['Q193']+df['Q194']+df['Q195']) / 17
Ethical_justification = pd.DataFrame(Ethical_justification, columns=['Ethical_justification'])                           
                           
Interest_for_politics = pd.DataFrame(df['Q199'].rename('Interest_for_politics'))
                           
Political_action = (df['Q209']+df['Q210']+df['Q211']+df['Q212']+df['Q213']+df['Q214']+df['Q215']+df['Q216']+
df['Q217']+df['Q218']+df['Q219']+df['Q220']) /12
Political_action = pd.DataFrame(Political_action, columns=['Political_action'])                         
                           
Electoral_integrity_battery = pd.DataFrame(df['Q232'].rename('Electoral_integrity_battery'))
                           
Importance_of_democracy = pd.DataFrame(df['Q250'].rename('Importance_of_democracy'))
                           
Perceived_democraticness = pd.DataFrame(df['Q251'].rename('Perceived_democraticness'))
                           
Satisfaction_with_the_political_system = pd.DataFrame(df['Q252'].rename('Satisfaction_with_system'))
                                                      
Respect_for_human_rights = pd.DataFrame(df['Q253'].rename('Respect_human_rights'))
                                        
Identity_levels = (df['Q255']+df['Q256']+df['Q257']+df['Q258']+df['Q259']) /5
Identity_levels = pd.DataFrame(Identity_levels, columns=['Identity_levels'])                           
                                        
Social_class = pd.DataFrame(df['Q287'].rename('Social_class'))



                                                
df_m = pd.concat([economic_values,corruption_preceptions, corruption_of_institutions, effect_of_immigration,secure_in_neighborhood,\
           worried_about_risks_and_war,science_and_technologie,importance_of_god,religion_and_science,moral_rules,\
          Ethical_justification,Interest_for_politics,Political_action,Electoral_integrity_battery,Importance_of_democracy,\
          Perceived_democraticness,Satisfaction_with_the_political_system, Respect_for_human_rights,Identity_levels,Social_class, df_m, df[['Q46']]],1)

# %%
df_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70867 entries, 0 to 70866
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   economic_values              70006 non-null  float64
#  1   corruption_preceptions       69750 non-null  float64
#  2   corruption_of_institutions   61207 non-null  float64
#  3   effect_of_immigration        61075 non-null  float64
#  4   secure_in_neighborhood       60280 non-null  float64
#  5   worried_about_risks_and_war  59374 non-null  float64
#  6   science_and_technologie      66460 non-null  float64
#  7   importance_of_god            68965 non-null  float64
#  8   religion_and_science         64407 non-null  float64
#  9   moral_rules                  68599 non-null  float64
#  10  Ethical_justification        53861 non-null  float64
#  11  Interest_for_politics        70376 non-null  float64
# ...

# %%
import numpy as np

# %%
def happy(x):
    if x==1 or x ==2:
        return "happy"
    elif x ==3 or x == 4:
        return "not_happy"
    else:
        return np.NaN

# %%
df_m['happy']=df_m.Q46.apply(happy)
df_m.drop('Q46',1, inplace=True)

# %%
t = ((df_m.isnull().sum())/df_m.shape[0]).to_frame()
t
# Out:
#                                     0
# economic_values              0.012150
# corruption_preceptions       0.015762
# corruption_of_institutions   0.136312
# effect_of_immigration        0.138174
# secure_in_neighborhood       0.149393
# worried_about_risks_and_war  0.162177
# science_and_technologie      0.062187
# importance_of_god            0.026839
# religion_and_science         0.091157
# moral_rules                  0.032004
# Ethical_justification        0.239971
# Interest_for_politics        0.006928
# Political_action             0.265257
# Electoral_integrity_battery  0.105874
# Importance_of_democracy      0.017469
# Perceived_democraticness     0.026317
# Satisfaction_with_system     0.037930
# Respect_human_rights         0.019642
# Identity_levels              0.072516
# Social_class                 0.030451
# nachbarn                     0.082704
# trust                        0.061665
# active                       0.127662
# financial                    0.005066
# ...

# %%
df_m.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21674 entries, 2 to 70866
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   economic_values              21674 non-null  float64
#  1   corruption_preceptions       21674 non-null  float64
#  2   corruption_of_institutions   21674 non-null  float64
#  3   effect_of_immigration        21674 non-null  float64
#  4   secure_in_neighborhood       21674 non-null  float64
#  5   worried_about_risks_and_war  21674 non-null  float64
#  6   science_and_technologie      21674 non-null  float64
#  7   importance_of_god            21674 non-null  float64
#  8   religion_and_science         21674 non-null  float64
#  9   moral_rules                  21674 non-null  float64
#  10  Ethical_justification        21674 non-null  float64
#  11  Interest_for_politics        21674 non-null  float64
# ...

# %%
import seaborn as sns

# %%
pd.concat([df_m.iloc[:,0:10], df_m['happy']],1)
# Out:
#        economic_values  corruption_preceptions  corruption_of_institutions  \
# 0                  5.0                     2.0                         NaN
# 1                  5.0                    10.0                         3.0
# 2                  7.0                     7.0                         2.0
# 3                  5.0                     5.0                         2.8
# 4                  4.0                     5.0                         1.8
# ...                ...                     ...                         ...
# 70862              5.0                     7.0                         3.0
# 70863              1.0                    10.0                         2.2
# 70864              1.0                    10.0                         2.0
# 70865              1.0                    10.0                         3.0
# 70866              1.0                    10.0                         3.0
#
#        effect_of_immigration  secure_in_neighborhood  \
# ...

# %%
sns.pairplot(pd.concat([df_m.iloc[:,0:5],  df_m['happy']],1),hue='happy', corner = True  )

# %%
sns.pairplot(pd.concat([df_m.iloc[:,6:11],  df_m['happy']],1),hue='happy', corner = True  )

# %%
sns.pairplot(pd.concat([df_m.iloc[:,12:18],  df_m['happy']],1),hue='happy', corner = True  )

# %%
sns.pairplot(pd.concat([df_m.iloc[:,19:24],  df_m['happy']],1),hue='happy', corner = True  )

# %%
sns.pairplot(pd.concat([df_m.iloc[:,25:29],  df_m['happy']],1),hue='happy', corner = True  )

# %%
def data_spliting (df,target, size = 0.2, random_state=42):
    """
    it takes dataframe and return train and test datasets
    """
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split( df.drop(target,1),df[target], test_size=size ,random_state=random_state)
    return  X_train, X_test, y_train, y_test

# %%
def data_balancing (df, target, over_sampeling = True, under_sampling = False):
    """
    it takes train dataframe and return either over sampled dataset or under sampled dataset or both them
    """
    from imblearn.under_sampling import RandomUnderSampler
    from imblearn.over_sampling import RandomOverSampler
    over = RandomOverSampler(random_state=0)
    under = RandomUnderSampler(random_state=0)
    
    X_train, X_test, y_train, y_test = data_spliting (df, target)
    
    if over_sampeling!=under_sampling:
        if over_sampeling:
            X_resample_over, y_resample_over = over.fit_resample(X_train, y_train)
            return X_resample_over, X_test, y_resample_over, y_test
        else:
            X_resample_under, y_resample_under = under.fit_resample(X_train, y_train)
            return X_resample_under,X_test, y_resample_under, y_test
    else:
        raise ValueError('Please choose either over_sampeling or under_sampeling')

# %%
def data_scaling (df, target, method = 'StandardScaler', balance = False, **kwargs):
    """
    it takes train and test dataframe and return scaled train and test dataframes
    method {'StandardScaler': StandardScaler, 'MinMaxScaler':MinMaxScaler}
    """
    from sklearn.preprocessing import StandardScaler, MinMaxScaler
    if method == 'StandardScaler':
        scaler = StandardScaler()
    elif method == 'MinMaxScaler':
        scaler = MinMaxScaler()
    else:
          raise ValueError("please chose a vaild method")
    
    
    if balance:
        X_train, X_test, y_train, y_test = data_balancing (df, target)
    else:
        X_train, X_test, y_train, y_test = data_spliting (df, target)
    
    X_train_s = scaler.fit_transform(X_train)
    X_test_s = scaler.transform(X_test)
    
    return X_train_s, X_test_s, y_train, y_test

# %%
def classification_model(X_train, X_test, y_train,y_test, classification_model = None ):
    """
    it takes dataframe and return f1 score of the model
    avaliable models:
    models = [
    BernoulliNB(),
    GaussianNB(),
    KNeighborsClassifier(),
    LogisticRegression(),
    SGDClassifier(),
    LinearSVC(),
    SVC(),
    DecisionTreeClassifier(criterion='gini',max_depth=None),
    RandomForestClassifier(n_estimators=600),
    AdaBoostClassifier(),
    MLPClassifier()
    ]
    """
    from sklearn.naive_bayes import MultinomialNB, BernoulliNB, GaussianNB
    from sklearn.neighbors import KNeighborsClassifier
    from sklearn.linear_model import LogisticRegression, SGDClassifier
    from sklearn.svm import LinearSVC, SVC
    from sklearn.neural_network import MLPClassifier
    from sklearn.tree import DecisionTreeClassifier
    from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
    from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
    model = {
    'BernoulliNB':BernoulliNB(),
    'GaussianNB':GaussianNB(),
    'KNeighborsClassifier': KNeighborsClassifier(),
    'LogisticRegression':LogisticRegression(),
    'SGDClassifier':SGDClassifier(),
    'SVC':SVC(),
    'DecisionTreeClassifier':DecisionTreeClassifier(),
    'RandomForestClassifier': RandomForestClassifier(n_estimators=600),
    'AdaBoostClassifier':AdaBoostClassifier(),
    'MLPClassifier':MLPClassifier()
    }
    if classification_model not in model.keys():
        raise ValueError ("this model is not avaliable")  
    
    
    
    
    if classification_model != 'KNeighborsClassifier':
        model = model[classification_model]
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        return y_test, y_pred
    else:
        acc = []
        for i in range(1, 40):
            neigh = KNeighborsClassifier(n_neighbors = i).fit(X_train,y_train)
            yhat = neigh.predict(X_test)
            acc.append(accuracy_score(y_test, yhat))
        n = acc.index(max(acc)) + 1
        neigh = KNeighborsClassifier(n_neighbors = n).fit(X_train,y_train)
        y_pred = neigh.predict(X_test)
        return y_test,y_pred

# %%
models = [
    'BernoulliNB',
    'GaussianNB',
    'KNeighborsClassifier',
    'LogisticRegression',
    'SGDClassifier',
    'SVC',
    'DecisionTreeClassifier',
    'RandomForestClassifier',
    'AdaBoostClassifier',
    'MLPClassifier'
]

# %%
X_train, X_test, y_train,y_test = data_spliting(df_m.dropna(), target='happy')

# %%
y_test.value_counts()
# Out:
# happy        3741
# not_happy     594
# Name: happy, dtype: int64

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, f1_score
import time

# %%
l_f1 = []
l_acc = []
for model in models:
    print("===============================================")
    print("Testing without scaling and resampling  " + model)
    now = time.time()
    list_of_labels = sorted(list(set(y_train)))
    fit = classification_model(X_train, X_test, y_train,y_test, classification_model=model)
    print("Learing time {0}s".format(time.time() - now))
    now = time.time()
    print("Predicting time {0}s".format(time.time() - now))
    print("===============================================")
    print("=================== Results ===================\n")
    print(classification_report(fit[0],fit[1]))
    print("============== Confusion Matrix ===============")
    print(confusion_matrix(fit[0],fit[1]))      
    print("===============================================\n\n")
    l_f1.append(f1_score(fit[0],fit[1],average='macro'))
    l_acc.append(accuracy_score(fit[0],fit[1]))
# Out:
# ...
# Testing without scaling and resampling  BernoulliNB
# Learing time 0.06661200523376465s
# Predicting time 2.1457672119140625e-06s
# ...
# =================== Results ===================
# /Users/aydin/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/aydin/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
without_scaling_resampling = pd.DataFrame(zip(models, l_acc,l_f1),columns=['model','accuracy','f1 score'])
without_scaling_resampling
# Out:
#                     model  accuracy  f1 score
# 0             BernoulliNB  0.862976  0.463224
# 1              GaussianNB  0.814302  0.617365
# 2    KNeighborsClassifier  0.865283  0.535293
# 3      LogisticRegression  0.860900  0.542748
# 4           SGDClassifier  0.848212  0.618097
# 5                     SVC  0.862976  0.463224
# 6  DecisionTreeClassifier  0.788927  0.572058
# 7  RandomForestClassifier  0.869666  0.551014
# 8      AdaBoostClassifier  0.862976  0.564396
# 9           MLPClassifier  0.854902  0.600225

# %%
X_train, X_test, y_train,y_test = data_scaling(df_m.dropna(), target='happy', balance=False)

# %%
l_f1 = []
l_acc = []
for model in models:
    print("===============================================")
    print("Testing with scaling and without resampling  " + model)
    now = time.time()
    list_of_labels = sorted(list(set(y_train)))
    fit = classification_model(X_train, X_test, y_train,y_test, classification_model=model)
    print("Learing time {0}s".format(time.time() - now))
    now = time.time()
    print("Predicting time {0}s".format(time.time() - now))
    print("===============================================")
    print("=================== Results ===================\n")
    print(classification_report(fit[0],fit[1]))
    print("============== Confusion Matrix ===============")
    print(confusion_matrix(fit[0],fit[1]))      
    print("===============================================\n\n")
    l_f1.append(f1_score(fit[0],fit[1],average='macro'))
    l_acc.append(accuracy_score(fit[0],fit[1]))
# Out:
# ...
# Testing with scaling and without resampling  BernoulliNB
# Learing time 0.20511889457702637s
# Predicting time 1.1920928955078125e-06s
# ...
# =================== Results ===================
#
#               precision    recall  f1-score   support
#
#        happy       0.89      0.92      0.90      3741
#    not_happy       0.36      0.28      0.32       594
#
#     accuracy                           0.83      4335
#    macro avg       0.62      0.60      0.61      4335
# weighted avg       0.82      0.83      0.82      4335
#
# ============== Confusion Matrix ===============
# [[3438  303]
#  [ 425  169]]
# ...
#
#
# ...
# Testing with scaling and without resampling  GaussianNB
# Learing time 0.042678117752075195s
# Predicting time 4.0531158447265625e-06s
# ...
# =================== Results ===================
#
#               precision    recall  f1-score   support
#
#        happy       0.90      0.89      0.89      3741
#    not_happy       0.33      0.35      0.34       594
#
# ...

# %%
wth_scaling_wthout_resampling = pd.DataFrame(zip(models, l_acc,l_f1),columns=['model','accuracy','f1 score'])
wth_scaling_wthout_resampling
# Out:
#                     model  accuracy  f1 score
# 0             BernoulliNB  0.832065  0.610667
# 1              GaussianNB  0.814302  0.617365
# 2    KNeighborsClassifier  0.869896  0.551207
# 3      LogisticRegression  0.861361  0.545414
# 4           SGDClassifier  0.862745  0.480885
# 5                     SVC  0.866436  0.520551
# 6  DecisionTreeClassifier  0.788005  0.578019
# 7  RandomForestClassifier  0.869204  0.549424
# 8      AdaBoostClassifier  0.862976  0.564396
# 9           MLPClassifier  0.849135  0.614853

# %%
X_train, X_test, y_train,y_test = data_balancing(df_m.dropna(), target='happy')

# %%
l_f1 = []
l_acc = []
for model in models:
    print("===============================================")
    print("Testing without scaling and with resampling  " + model)
    now = time.time()
    list_of_labels = sorted(list(set(y_train)))
    fit = classification_model(X_train, X_test, y_train,y_test, classification_model=model)
    print("Learing time {0}s".format(time.time() - now))
    now = time.time()
    print("Predicting time {0}s".format(time.time() - now))
    print("===============================================")
    print("=================== Results ===================\n")
    print(classification_report(fit[0],fit[1]))
    print("============== Confusion Matrix ===============")
    print(confusion_matrix(fit[0],fit[1]))      
    print("===============================================\n\n")
    l_f1.append(f1_score(fit[0],fit[1],average='macro'))
    l_acc.append(accuracy_score(fit[0],fit[1]))
# Out:
# ...
# Testing without scaling and with resampling  BernoulliNB
# Learing time 0.11937093734741211s
# Predicting time 2.1457672119140625e-06s
# ...
# =================== Results ===================
#
#               precision    recall  f1-score   support
#
#        happy       0.88      0.32      0.47      3741
#    not_happy       0.14      0.72      0.24       594
#
#     accuracy                           0.37      4335
#    macro avg       0.51      0.52      0.35      4335
# weighted avg       0.78      0.37      0.44      4335
#
# ============== Confusion Matrix ===============
# [[1189 2552]
#  [ 169  425]]
# ...
#
#
# ...
# Testing without scaling and with resampling  GaussianNB
# Learing time 0.07666611671447754s
# Predicting time 1.1920928955078125e-06s
# ...
# =================== Results ===================
#
#               precision    recall  f1-score   support
#
#        happy       0.92      0.71      0.80      3741
#    not_happy       0.25      0.63      0.36       594
#
# ...

# %%
wthout_scaling_wth_resampling = pd.DataFrame(zip(models, l_acc,l_f1),columns=['model','accuracy','f1 score'])
wthout_scaling_wth_resampling
# Out:
#                     model  accuracy  f1 score
# 0             BernoulliNB  0.372318  0.352197
# 1              GaussianNB  0.694348  0.579433
# 2    KNeighborsClassifier  0.814764  0.588652
# 3      LogisticRegression  0.717647  0.608488
# 4           SGDClassifier  0.820531  0.643455
# 5                     SVC  0.733795  0.620169
# 6  DecisionTreeClassifier  0.792849  0.572869
# 7  RandomForestClassifier  0.868973  0.584471
# 8      AdaBoostClassifier  0.732411  0.619017
# 9           MLPClassifier  0.721569  0.593071

# %%
X_train, X_test, y_train,y_test = data_scaling(df_m.dropna(), target='happy', balanced = True)

# %%
l_f1 = []
l_acc = []
for model in models:
    print("===============================================")
    print("Testing with scaling and with resampling  " + model)
    now = time.time()
    list_of_labels = sorted(list(set(y_train)))
    fit = classification_model(X_train, X_test, y_train,y_test, classification_model=model)
    print("Learing time {0}s".format(time.time() - now))
    now = time.time()
    print("Predicting time {0}s".format(time.time() - now))
    print("===============================================")
    print("=================== Results ===================\n")
    print(classification_report(fit[0],fit[1]))
    print("============== Confusion Matrix ===============")
    print(confusion_matrix(fit[0],fit[1]))      
    print("===============================================\n\n")
    l_f1.append(f1_score(fit[0],fit[1],average='macro'))
    l_acc.append(accuracy_score(fit[0],fit[1]))
# Out:
# ...
# Testing with scaling and with resampling  BernoulliNB
# Learing time 0.07217907905578613s
# Predicting time 3.0994415283203125e-06s
# ...
# =================== Results ===================
#
#               precision    recall  f1-score   support
#
#        happy       0.89      0.92      0.90      3741
#    not_happy       0.36      0.28      0.32       594
#
#     accuracy                           0.83      4335
#    macro avg       0.62      0.60      0.61      4335
# weighted avg       0.82      0.83      0.82      4335
#
# ============== Confusion Matrix ===============
# [[3438  303]
#  [ 425  169]]
# ...
#
#
# ...
# Testing with scaling and with resampling  GaussianNB
# Learing time 0.06211113929748535s
# Predicting time 1.9073486328125e-06s
# ...
# =================== Results ===================
#
#               precision    recall  f1-score   support
#
#        happy       0.90      0.89      0.89      3741
#    not_happy       0.33      0.35      0.34       594
#
# ...

# %%
wth_scaling_wth_resampling = pd.DataFrame(zip(models, l_acc,l_f1),columns=['model','accuracy','f1 score'])
wth_scaling_wth_resampling
# Out:
#                     model  accuracy  f1 score
# 0             BernoulliNB  0.832065  0.610667
# 1              GaussianNB  0.814302  0.617365
# 2    KNeighborsClassifier  0.869896  0.551207
# 3      LogisticRegression  0.861361  0.545414
# 4           SGDClassifier  0.863899  0.471778
# 5                     SVC  0.866436  0.520551
# 6  DecisionTreeClassifier  0.786621  0.569101
# 7  RandomForestClassifier  0.869204  0.549424
# 8      AdaBoostClassifier  0.862976  0.564396
# 9           MLPClassifier  0.847290  0.605052

# %%
pd.concat([without_scaling_resampling,wth_scaling_wth_resampling,wthout_scaling_wth_resampling,wth_scaling_wthout_resampling],1)
# Out:
#                     model  accuracy  f1 score                   model  \
# 0             BernoulliNB  0.862976  0.463224             BernoulliNB
# 1              GaussianNB  0.814302  0.617365              GaussianNB
# 2    KNeighborsClassifier  0.865283  0.535293    KNeighborsClassifier
# 3      LogisticRegression  0.860900  0.542748      LogisticRegression
# 4           SGDClassifier  0.848212  0.618097           SGDClassifier
# 5                     SVC  0.862976  0.463224                     SVC
# 6  DecisionTreeClassifier  0.788927  0.572058  DecisionTreeClassifier
# 7  RandomForestClassifier  0.869666  0.551014  RandomForestClassifier
# 8      AdaBoostClassifier  0.862976  0.564396      AdaBoostClassifier
# 9           MLPClassifier  0.854902  0.600225           MLPClassifier
#
#    accuracy  f1 score                   model  accuracy  f1 score  \
# 0  0.832065  0.610667             BernoulliNB  0.372318  0.352197
# ...

# %%
from sklearn.model_selection import GridSearchCV

# %%
X_train, X_test, y_train,y_test = data_scaling(df_m.dropna(), target='happy', balanced = True)

# %%
from sklearn.ensemble import RandomForestClassifier
rf_params = {"n_estimators":[100, 300,600],
              "max_depth":[17,20,22],
              "max_features": [10,12,16],
            }
rf = RandomForestClassifier()
rf_cv_model = GridSearchCV(rf, rf_params, cv = 5, n_jobs = -1, verbose = 2).fit(X_train, y_train)
rf_cv_model.best_params_
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# {'max_depth': 20, 'max_features': 12, 'n_estimators': 600}

# %%
y_pred = rf_cv_model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[3684   57]
#  [ 511   83]]
#               precision    recall  f1-score   support
#
#        happy       0.88      0.98      0.93      3741
#    not_happy       0.59      0.14      0.23       594
#
#     accuracy                           0.87      4335
#    macro avg       0.74      0.56      0.58      4335
# weighted avg       0.84      0.87      0.83      4335

# %%
rf_params = {"n_estimators":[100, 300,600],
              "max_depth":[11,13,17],
              "max_features": [8,10,12],
              "min_samples_split": [6,8,10]}
rf = RandomForestClassifier()
rf_tuned = GridSearchCV(rf, rf_params, cv = 5, n_jobs = -1, verbose = 2).fit(X_train, y_train)


y_pred = rf_tuned.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[3695   46]
#  [ 524   70]]
#               precision    recall  f1-score   support
#
#        happy       0.88      0.99      0.93      3741
#    not_happy       0.60      0.12      0.20       594
#
#     accuracy                           0.87      4335
#    macro avg       0.74      0.55      0.56      4335
# weighted avg       0.84      0.87      0.83      4335

# %%
from sklearn.naive_bayes import BernoulliNB
bel_params = {'alpha': [0.1,0.01, 1]} 
bel = BernoulliNB()
bel_model = GridSearchCV(bel, bel_params, cv = 5, verbose=3,refit=True).fit(X_train, y_train)
bel_model.best_params_
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END ......................................alpha=0.1; total time=   0.1s
# [CV 2/5] END ......................................alpha=0.1; total time=   0.1s
# [CV 3/5] END ......................................alpha=0.1; total time=   0.1s
# [CV 4/5] END ......................................alpha=0.1; total time=   0.1s
# [CV 5/5] END ......................................alpha=0.1; total time=   0.2s
# [CV 1/5] END .....................................alpha=0.01; total time=   0.1s
# [CV 2/5] END .....................................alpha=0.01; total time=   0.1s
# [CV 3/5] END .....................................alpha=0.01; total time=   0.1s
# [CV 4/5] END .....................................alpha=0.01; total time=   0.1s
# [CV 5/5] END .....................................alpha=0.01; total time=   0.1s
# [CV 1/5] END ........................................alpha=1; total time=   0.1s
# ...

# %%
y_pred = bel_model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[3438  303]
#  [ 425  169]]
#               precision    recall  f1-score   support
#
#        happy       0.89      0.92      0.90      3741
#    not_happy       0.36      0.28      0.32       594
#
#     accuracy                           0.83      4335
#    macro avg       0.62      0.60      0.61      4335
# weighted avg       0.82      0.83      0.82      4335

# %%
from sklearn.svm import SVC
svm_params = {'C': [0.1,1, 10], 'gamma': [1,0.1,0.01,0.001], 'kernel': ['rbf','linear']} 
svm = SVC()
svm_cv_model = GridSearchCV(svm, svm_params, cv = 3, verbose=3,refit=True).fit(X_train, y_train)
svm_cv_model.best_params_
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# [CV 1/3] END .....................C=0.1, gamma=1, kernel=rbf; total time=  48.7s
# [CV 2/3] END .....................C=0.1, gamma=1, kernel=rbf; total time=  43.4s
# [CV 3/3] END .....................C=0.1, gamma=1, kernel=rbf; total time=  42.4s
# [CV 1/3] END ..................C=0.1, gamma=1, kernel=linear; total time=   3.4s
# [CV 2/3] END ..................C=0.1, gamma=1, kernel=linear; total time=   3.4s
# [CV 3/3] END ..................C=0.1, gamma=1, kernel=linear; total time=   3.4s
# [CV 1/3] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=  20.0s
# [CV 2/3] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=  21.1s
# [CV 3/3] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=  20.3s
# [CV 1/3] END ................C=0.1, gamma=0.1, kernel=linear; total time=   3.5s
# [CV 2/3] END ................C=0.1, gamma=0.1, kernel=linear; total time=   3.5s
# ...

# %%
y_pred = svm_cv_model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[3708   33]
#  [ 550   44]]
#               precision    recall  f1-score   support
#
#        happy       0.87      0.99      0.93      3741
#    not_happy       0.57      0.07      0.13       594
#
#     accuracy                           0.87      4335
#    macro avg       0.72      0.53      0.53      4335
# weighted avg       0.83      0.87      0.82      4335

# %%
from sklearn.neural_network import MLPClassifier
ml_params = {'alpha': [0.001, 0.0001, 0.00001], 'activation':['logistic', 'relu'], 'learning_rate':['constant', 'adaptive']} 
ml = MLPClassifier()                                                          
ml_cv_model = GridSearchCV(ml, ml_params, cv = 3, verbose=3,refit=True).fit(X_train, y_train)
ml_cv_model.best_params_
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# /Users/aydin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# [CV 1/3] END activation=logistic, alpha=0.001, learning_rate=constant; total time=  15.6s
# /Users/aydin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# [CV 2/3] END activation=logistic, alpha=0.001, learning_rate=constant; total time=  14.3s
# [CV 3/3] END activation=logistic, alpha=0.001, learning_rate=constant; total time=   1.9s
# [CV 1/3] END activation=logistic, alpha=0.001, learning_rate=adaptive; total time=   3.0s
# ...

# %%
y_pred = ml_cv_model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[3667   74]
#  [ 533   61]]
#               precision    recall  f1-score   support
#
#        happy       0.87      0.98      0.92      3741
#    not_happy       0.45      0.10      0.17       594
#
#     accuracy                           0.86      4335
#    macro avg       0.66      0.54      0.55      4335
# weighted avg       0.82      0.86      0.82      4335

# %%
from sklearn.ensemble import VotingClassifier

# %%
rf_model = RandomForestClassifier(max_depth=20, max_features = 12,n_estimators = 600 )
bel_model = BernoulliNB(alpha = 1)
svm = SVC(C=10, gamma = 0.01, kernel ='rbf')
ml = MLPClassifier(activation = 'relu',alpha =0.0001, learning_rate =  'constant')

# %%
eclf1 = VotingClassifier(estimators=[ ('random', rf_model),('bel',bel_model), ('svm', svm),('ml',ml)], voting='hard')
eclf1 = eclf1.fit(X_train, y_train)
# Out:
# /Users/aydin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
y_pred = eclf1.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[3703   38]
#  [ 543   51]]
#               precision    recall  f1-score   support
#
#        happy       0.87      0.99      0.93      3741
#    not_happy       0.57      0.09      0.15       594
#
#     accuracy                           0.87      4335
#    macro avg       0.72      0.54      0.54      4335
# weighted avg       0.83      0.87      0.82      4335

# %%
eclf2 = VotingClassifier(estimators=[ ('random', rf_model),('bel',bel_model), ('svm', svm),('ml',ml)], voting='soft')
eclf2 = eclf1.fit(X_train, y_train)
# Out:
# /Users/aydin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
y_pred = eclf2.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[3698   43]
#  [ 546   48]]
#               precision    recall  f1-score   support
#
#        happy       0.87      0.99      0.93      3741
#    not_happy       0.53      0.08      0.14       594
#
#     accuracy                           0.86      4335
#    macro avg       0.70      0.53      0.53      4335
# weighted avg       0.82      0.86      0.82      4335

# %%
from sklearn.model_selection import cross_val_score

# %%
df_ = df_m.dropna()
X, y = df_.drop('happy',1), df_['happy']

# %%
y.value_counts()
# Out:
# happy        18813
# not_happy     2861
# Name: happy, dtype: int64

# %%
cross_val_score(rf_model,X,y,cv=4).mean()
# Out:
# 0.8649530203225856

# %%
cross_val_score(bel_model,X,y,cv=4,).mean()
# Out:
# 0.8679985267101229

# %%
cross_val_score(ml,X,y,cv=4,).mean()
# Out:
# /Users/aydin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/aydin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/aydin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 0.848389076251743

# %%
cross_val_score(eclf2,X,y,cv=4,).mean()
# Out:
# /Users/aydin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/aydin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 0.8661528101601144

# %%
rf_model = RandomForestClassifier(max_depth=20, max_features = 12,n_estimators = 600 ).fit(X_train, y_train)

# %%
t = pd.DataFrame(rf_model.feature_importances_, index=list(X.columns)).sort_values(0, ascending=False)
t = t.rename(columns= {0:'values'})
t
# Out:
#                                values
# financial                    0.118503
# Ethical_justification        0.058156
# science_and_technologie      0.057459
# secure_in_neighborhood       0.047526
# trust                        0.046855
# Political_action             0.046323
# effect_of_immigration        0.042934
# corruption_of_institutions   0.040600
# Identity_levels              0.039628
# worried_about_risks_and_war  0.036836
# active                       0.036191
# Perceived_democraticness     0.034162
# nachbarn                     0.033658
# moral_rules                  0.032992
# Satisfaction_with_system     0.031860
# economic_values              0.030368
# comparing_parents            0.028206
# religion_and_science         0.027603
# corruption_preceptions       0.025991
# Importance_of_democracy      0.025468
# importance_of_god            0.021919
# Respect_human_rights         0.019528
# Electoral_integrity_battery  0.019346
# Interest_for_politics        0.019238
# ...

# %%
bel_model = BernoulliNB(alpha = 1).fit(X_train,y_train)

# %%
bel_model.coef_
# Out:
# array([[-0.66747686, -0.35686384, -0.5592853 , -0.57247913, -0.82334723,
#         -1.01413828, -0.75542588, -0.41454099, -0.88976167, -0.89298575,
#         -0.87485192, -0.51627603, -0.62130836, -1.01779014, -0.49943199,
#         -1.0190104 , -1.06780057, -0.61476704, -0.73683798, -0.730413  ,
#         -0.46516739, -0.57874874, -1.09773123, -1.6134123 , -0.72584886,
#         -0.46586939, -0.43271719, -1.94635097, -1.06651933]])

# %%
t = pd.DataFrame(-bel_model.coef_[0], index=list(X.columns)).sort_values(0, ascending=False)
t = t.rename(columns= {0:'values'})
t
# Out:
# /Users/aydin/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute coef_ was deprecated in version 0.24 and will be removed in 1.1 (renaming of 0.26).
#   warnings.warn(msg, category=FutureWarning)
#                                values
# family                       1.946351
# financial                    1.613412
# active                       1.097731
# Satisfaction_with_system     1.067801
# work                         1.066519
# Perceived_democraticness     1.019010
# Electoral_integrity_battery  1.017790
# worried_about_risks_and_war  1.014138
# moral_rules                  0.892986
# religion_and_science         0.889762
# Ethical_justification        0.874852
# secure_in_neighborhood       0.823347
# science_and_technologie      0.755426
# Identity_levels              0.736838
# Social_class                 0.730413
# main_goal                    0.725849
# economic_values              0.667477
# ...

# %%
import pickle
pickle.dump(model, open("saved_model", 'wb'))
